# %%
import pandas as pd

raw_df = pd.read_csv("Tokyo_20251_20252.csv", encoding='cp932')

raw_df.columns = raw_df.columns.str.strip()

sel_col = [
    '市区町村名',  
    '最寄駅：名称', 
    '最寄駅：距離（分）',
    '取引価格（総額）', 
    '間取り', 
    '面積（㎡）',
    '建築年',
    '建物の構造'
]

filter_df = raw_df[sel_col].copy()

filter_df.to_csv("filter_tokyo_real_estate.csv", index=False, encoding='utf-8-sig')

print("保存完了")
# Out:
# 保存完了
